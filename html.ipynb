# %%
import numpy as np
import pandas as pd
import lxml

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/100_metres')

# %%
dfs[3]
# Out:
#     Ath.#  Perf.# Time (s) Wind (m/s)             Athlete
# 0     1.0     1.0     9.58       +0.9          Usain Bolt  \
# 1     NaN     2.0     9.63       +1.5             Bolt #2
# 2     NaN     3.0     9.69       ±0.0             Bolt #3
# 3     2.0     3.0     9.69       +2.0           Tyson Gay
# 4     2.0     3.0     9.69       −0.1         Yohan Blake
# 5     NaN     6.0     9.71       +0.9              Gay #2
# 6     NaN     7.0     9.72       +1.7             Bolt #4
# 7     4.0     7.0     9.72       +0.2        Asafa Powell
# 8     NaN     9.0     9.74       +1.7           Powell #2
# 9     5.0     9.0     9.74       +0.9       Justin Gatlin
# 10    NaN    11.0     9.75       +1.1            Blake #2
# 11    NaN    11.0     9.75       +1.5            Blake #3
# 12    NaN    11.0     9.75       +0.9           Gatlin #2
# 13    NaN    11.0     9.75       +1.4           Gatlin #3
# 14    NaN    15.0     9.76       +1.8             Bolt #5
# ...
